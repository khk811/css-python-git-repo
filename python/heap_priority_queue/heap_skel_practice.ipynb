# %%
class Heap:
    def get_parent_idx(self, idx):
        #부모의 인덱스를 알려주는 것.
        parent_idx = idx // 2
        return parent_idx
        
    def get_left_child_idx(self, idx):
        #왼쪽 자식의 인덱스를 알려줌.
        left_child_idx = idx * 2
        return left_child_idx
        
    def get_right_child_idx(self, idx):
        #오른쪽 자식의 인덱스를 알려줌
        right_child_idx = (idx * 2) + 1
        return right_child_idx
    
    def __init__(self, s_min_mac = "min")
        #개시자
        self.dynamic_arr = [None, ]
        self.idx = self.dynamic_arr[data?]
        self.num_of_data = 0
        
    def is_empty(self):
        if self.sum_of_data == 0:
            return True
        else:
            return False
        
    def size(self):
        return self.num_of_data
    
    def insert(self, data):
        #노드의 삽입
        self.dynamic_arr.append(data)
        parent_idx = self.idx // 2
        
        self.sum_of_data += 1
        
        
        while data < self.dynamic_arr[parent_idx]:
            if data  < arr[parent_idx]:
                #(index switch)
                temp_ = self.dynamic_arr[parent_idx]
                self.dynamic_arr[parent_idx] = self.dynamic_arr[self.idx]
                self.dynamic_arr[self.idx] = temp
            else:
                break
               
        #(last node data = [len(arr)])
        
    def which_is_prior_child(self, idx):
        #단말노드면 none, 우선순위?(최소힙이니까 작은 값?)가 높은 자식노드의 인덱스
        # last_node = self.sum_of_data?
        
        left_child_idx = idx * 2
        #왼쪽 자식노드가 있다고 하고 가정한것.
        
        if left_child_idx  > self.num_of_data:
            #idx = term_node
            return None
        elif left_child_idx == num_of_data:
            #idx has one (left) child node
            return self.dynamic_arr[left_child_idx]
        elif left_child < num_of_data:
            #idx has two children node
            return ?
            
        
        
    def delete(self):
        root_node = self.dynamic_arr[1]
        self.dynamic_arr.pop([1])
        
        #heap sort
        self.dynamic_arr.insert(1, (last_node))
        
        while last_node < self.dynamic_arr[]:
            if last_node < self.dynamic_arr[]:
            #index switching
            else:
                break
        
        return root_node?
        
    #직접 다이나믹 어레이에 접근해서 출력해볼것(논리적으로 트리가 어떻게 들어갔는지 확인할것.)
